# %%
pip install pandas numpy matplotlib
# Out:
# Requirement already satisfied: pandas in d:\anaconda\envs\tfenv\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in d:\anaconda\envs\tfenv\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in d:\anaconda\envs\tfenv\lib\site-packages (3.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\tfenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\tfenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\envs\tfenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\tfenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in d:\anaconda\envs\tfenv\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in d:\anaconda\envs\tfenv\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in d:\anaconda\envs\tfenv\lib\site-packages (3.10.3)
# Requirement already satisfied: scikit-learn in d:\anaconda\envs\tfenv\lib\site-packages (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\tfenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\tfenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\envs\tfenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\tfenv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in d:\anaconda\envs\tfenv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\envs\tfenv\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\envs\tfenv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\tfenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import gradio as gr

# %%
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import numpy as np # Importing NumPy for numerical operations and array manipulations
import matplotlib.pyplot as plt # Importing Matplotlib for plotting graphs and visualizations
import seaborn as sns # Importing Seaborn for statistical data visualization, built on top of Matplotlib
import tensorflow as tf # Importing TensorFlow for building and training machine Learning models
from tensorflow import keras # Importing Keras, a high-Level API for TensorFlow, to simplify model building
#from tensorflow.keras import Layer # Importing Layer class for creating custom Layers in Keras
from tensorflow.keras.models import Sequential # Importing Sequential model for building neural networks Layer-by-Layer
from tensorflow.keras.layers import Rescaling , GlobalAveragePooling2D
from tensorflow.keras import layers, optimizers, callbacks # Importing various modules for Layers, optimizers, and callbacks in
from sklearn.utils.class_weight import compute_class_weight # Importing function to compute class weights for imbalanced dataset
from tensorflow.keras.applications import EfficientNetV2B2 # Importing EfficientNetV2S model for transfer Learning
from sklearn.metrics import confusion_matrix, classification_report # Importing functions to evaluate model performance
import gradio as gr # Importing Gradio for creating interactive web interfaces for machine Learning models

# %%
dataset_dir= r"D:\archive\Garbage classification\Garbage classification"
image_size = (224, 224)
batch_size = 32
seed = 42

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
dataset_dir,
validation_split=0.2,
subset="training",
seed=seed,
shuffle = True,
image_size=image_size,
batch_size=batch_size

)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
dataset_dir,
validation_split=0.2,
subset="validation",
seed=seed,
shuffle = True,
image_size=image_size,
batch_size=batch_size
)
val_class= val_ds.class_names
# Out:
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
# Get the total number of batches in the validation dataset
val_batches = tf.data.experimental.cardinality(val_ds)

# Split the validation dataset into two equal parts:
# First half becomes the test dataset
test_ds = val_ds.take(val_batches // 2)

# Second half remains as the validation dataset
val_dat = val_ds.skip(val_batches // 2)

# Optimize test dataset by caching and prefetching to improve perf
test_ds_eval = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
 for i in range(12):
   ax = plt.subplot(4, 3, i + 1)
   plt.imshow(images[i].numpy().astype("uint8"))
   plt.title(train_ds.class_names[labels[i]])
   plt.axis("off")

# %%
def count_distribution(dataset, class_names) :
 total = 0
 counts = {name: 0 for name in class_names}
 for _, labels in dataset:
  for label in labels.numpy():
   class_name = class_names[label]
   counts[class_name] += 1
   total += 1
 for k in counts:
  counts [k] = round( (counts [k] / total) * 100, 2) # Convert t
 return counts

# %%
# Function to plot class distribution
def simple_bar_plot(dist, title):
 plt.bar(dist.keys(), dist.values(), color='cornflowerblue')
 plt.title(title)
 plt.ylabel('Percentage (%)')
 plt.xticks(rotation=45)
 plt.ylim(0, 100)
 plt.tight_layout()
 plt.show()

# %%
class_names = train_ds. class_names
# Helper to count class distribution in dataset
def get_distribution(dataset, class_names):
 counts = {k: 0 for k in class_names}
 total = 0
 for images, labels in dataset:
     for label in labels:
      class_name = class_names[int(label)]
      counts[class_name] += 1
      total += 1

 if total == 0:
  return counts

 for k in counts:
   counts[k] = round((counts[k] / total) * 100, 2)
 return counts
# Compute distributions

train_dist = get_distribution(train_ds, class_names)
val_dist = get_distribution(val_ds, class_names)
test_dist = get_distribution(test_ds, class_names)
# Compute overall distribution from train + val
overall_dist = {}
for k in class_names:
  overall_dist[k] = round((train_dist.get(k, 0) + val_dist.get(k, 0)) /2,2)
# Print results
print("Train Distribution:", train_dist)
print("Validation Distribution:", val_dist)
print("Test Distribution:", test_dist)
print("Overall Distribution (Train + Val Avg):", overall_dist)
# Out:
# Train Distribution: {'cardboard': 16.52, 'glass': 19.73, 'metal': 15.92, 'paper': 23.29, 'plastic': 19.44, 'trash': 5.09}
# Validation Distribution: {'cardboard': 13.66, 'glass': 20.2, 'metal': 17.43, 'paper': 24.36, 'plastic': 17.62, 'trash': 6.73}
# Test Distribution: {'cardboard': 14.06, 'glass': 17.58, 'metal': 16.8, 'paper': 25.0, 'plastic': 19.14, 'trash': 7.42}
# Overall Distribution (Train + Val Avg): {'cardboard': 15.09, 'glass': 19.96, 'metal': 16.68, 'paper': 23.82, 'plastic': 18.53, 'trash': 5.91}

# %%
# Show visualizations
simple_bar_plot(train_dist, "Training Set Class Distribution (%)")
simple_bar_plot(val_dist, "Validation Set Class Distribution (%)")
simple_bar_plot(test_dist, "Test Set Class Distribution (%)")
simple_bar_plot(overall_dist, "Overall Class Distribution (%)")

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# Count class occurrences and prepare label list
class_counts = {i: 0 for i in range(len(class_names))}
all_labels = []
for images, labels in train_ds:
  for label in labels.numpy():
    if isinstance(label, np.ndarray): # handle one-hot encoded case
      label = np.argmax(label)
    class_counts[label] += 1
    all_labels.append(label)
# Compute class weights (ndex aligned)
class_weights_array = compute_class_weight(
  class_weight='balanced',
  classes=np.unique(all_labels),# use actual labels present in the data
  y=all_labels)

# Create dictionary mapping class index to weight
class_weights = {i: w for i, w in zip(np.unique(all_labels), class_weights_array)}

# %%
print("Class Counts:", class_counts)
print("Class Weights:", class_weights)
# Out:
# Class Counts: {0: 334, 1: 399, 2: 322, 3: 471, 4: 393, 5: 103}
# Class Weights: {np.int32(0): np.float64(1.0089820359281436), np.int32(1): np.float64(0.8446115288220551), np.int32(2): np.float64(1.046583850931677), np.int32(3): np.float64(0.7154989384288747), np.int32(4): np.float64(0.8575063613231552), np.int32(5): np.float64(3.2718446601941746)}

# %%
#  Define data augmentation pipeline
data_augmentation = Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# %%
#  Load the pretrained MobileNetV3Small model (without the top classification layer)
base_model = EfficientNetV2B2(include_top=False, input_shape=(224, 224, 3),include_preprocessing=True, weights='imagenet')


#  Freeze early layers (to retain general pretrained features)
base_model.trainable = True
for layer in base_model.layers[:100]:  # You can adjust this number
    layer.trainable = False

# %%
#  Build the final model
model = Sequential([
    layers.Input(shape=(224, 224, 3)),
    data_augmentation,
    base_model,
    GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(6, activation='softmax')  # Change to your number of classes
])

# %%
# ⚙️ Compile the model
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Define an EarlyStopping callback to stop training when validation loss stops improving
early = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',            # Metric to monitor (validation loss here)
    patience=3,                   # Number of epochs to wait after last improvement before stopping
    restore_best_weights=True     # After stopping, restore the model weights from the epoch with the best val_loss
)

# %%
# Set the number of epochs to train the model
epochs = 20  # Number of times the model will go through the entire dataset

# Train the model using the fit function
history = model.fit(
    train_ds,                # Training dataset used to adjust model weights
    validation_data=val_ds,   # Validation dataset to monitor performance on unseen data
    epochs=epochs,           # Number of training cycles, referencing the variable set earlier
    class_weight=class_weights,  # Handles class imbalances by assigning appropriate weights
    batch_size=32,           # Number of samples processed in each training step
    callbacks=[early]        # Implements early stopping to prevent unnecessary training
)
# Out:
# Epoch 1/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.3556 - loss: 1.6540 - val_accuracy: 0.7465 - val_loss: 0.9358
# Epoch 2/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - accuracy: 0.7530 - loss: 0.8707 - val_accuracy: 0.8455 - val_loss: 0.5303
# Epoch 3/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.8578 - loss: 0.4842 - val_accuracy: 0.8950 - val_loss: 0.3668
# Epoch 4/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9060 - loss: 0.3212 - val_accuracy: 0.9109 - val_loss: 0.3016
# Epoch 5/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.9384 - loss: 0.2099 - val_accuracy: 0.9208 - val_loss: 0.2713
# Epoch 6/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.9602 - loss: 0.1448 - val_accuracy: 0.9248 - val_loss: 0.2462
# Epoch 7/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.9627 - loss: 0.1286 - val_accuracy: 0.9208 - val_loss: 0.2461
# Epoch 8/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9783 - loss: 0.0897 - val_accuracy: 0.9248 - val_loss: 0.2311
# Epoch 9/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.9685 - loss: 0.1061 - val_accuracy: 0.9386 - val_loss: 0.2261
# Epoch 10/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9802 - loss: 0.0679 - val_accuracy: 0.9307 - val_loss: 0.2327
# Epoch 11/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.9822 - loss: 0.0602 - val_accuracy: 0.9228 - val_loss: 0.2541
# Epoch 12/20
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9894 - loss: 0.0451 - val_accuracy: 0.9307 - val_loss: 0.2386

# %%
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 646ms/step - accuracy: 0.9081 - loss: 0.2328
# Test Accuracy: 92.19%

# %%
# 📝 Summary (optional but useful)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b2 (Functional)  │ (None, 7, 7, 1408)     │     8,769,374 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1408)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1408)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │         8,454 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,727,114 (94.33 MB)
#  Trainable params: 7,974,642 (30.42 MB)
#  Non-trainable params: 803,186 (3.06 MB)
#  Optimizer params: 15,949,286 (60.84 MB)

# %%
base_model.summary() # Print the architecture summary of the base model
# Out:
# Model: "efficientnetv2-b2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          0 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │        864 │ normalization[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 112, 112,  │      4,608 │ stem_activation[… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 112, 112,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_ac… │ (None, 112, 112,  │          0 │ block1a_project_… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_co… │ (None, 112, 112,  │      2,304 │ block1a_project_… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_bn  │ (None, 112, 112,  │         64 │ block1b_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_ac… │ (None, 112, 112,  │          0 │ block1b_project_… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_drop        │ (None, 112, 112,  │          0 │ block1b_project_… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_add (Add)   │ (None, 112, 112,  │          0 │ block1b_drop[0][… │
# │                     │ 16)               │            │ block1a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 56, 56,    │      9,216 │ block1b_add[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 56, 56,    │        256 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 56, 56,    │          0 │ block2a_expand_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 56, 56,    │      2,048 │ block2a_expand_a… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 56, 56,    │        128 │ block2a_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 56, 56,    │     36,864 │ block2a_project_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 56, 56,    │        512 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 56, 56,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 56, 56,    │      4,096 │ block2b_expand_a… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 56, 56,    │        128 │ block2b_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 56, 56,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 56, 56,    │          0 │ block2b_drop[0][… │
# │                     │ 32)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_conv │ (None, 56, 56,    │     36,864 │ block2b_add[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_bn   │ (None, 56, 56,    │        512 │ block2c_expand_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_act… │ (None, 56, 56,    │          0 │ block2c_expand_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_co… │ (None, 56, 56,    │      4,096 │ block2c_expand_a… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_bn  │ (None, 56, 56,    │        128 │ block2c_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_drop        │ (None, 56, 56,    │          0 │ block2c_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_add (Add)   │ (None, 56, 56,    │          0 │ block2c_drop[0][… │
# │                     │ 32)               │            │ block2b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 28, 28,    │     36,864 │ block2c_add[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 28, 28,    │        512 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 28, 28,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 28, 28,    │      7,168 │ block3a_expand_a… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 28, 28,    │        224 │ block3a_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 28, 28,    │    112,896 │ block3a_project_… │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 28, 28,    │        896 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 28, 28,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 28, 28,    │     12,544 │ block3b_expand_a… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 28, 28,    │        224 │ block3b_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 28, 28,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 28, 28,    │          0 │ block3b_drop[0][… │
# │                     │ 56)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_conv │ (None, 28, 28,    │    112,896 │ block3b_add[0][0] │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_bn   │ (None, 28, 28,    │        896 │ block3c_expand_c… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_act… │ (None, 28, 28,    │          0 │ block3c_expand_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_co… │ (None, 28, 28,    │     12,544 │ block3c_expand_a… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_bn  │ (None, 28, 28,    │        224 │ block3c_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_drop        │ (None, 28, 28,    │          0 │ block3c_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_add (Add)   │ (None, 28, 28,    │          0 │ block3c_drop[0][… │
# │                     │ 56)               │            │ block3b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 28, 28,    │     12,544 │ block3c_add[0][0] │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 28, 28,    │        896 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 28, 28,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv2     │ (None, 14, 14,    │      2,016 │ block4a_expand_a… │
# │ (DepthwiseConv2D)   │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 14, 14,    │        896 │ block4a_dwconv2[… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 14, 14,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 224)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 224) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 14)  │      3,150 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 224) │      3,360 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 14, 14,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 224)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 14, 14,    │     23,296 │ block4a_se_excit… │
# │ (Conv2D)            │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 14, 14,    │        416 │ block4a_project_… │
# │ (BatchNormalizatio… │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 14, 14,    │     43,264 │ block4a_project_… │
# │ (Conv2D)            │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 14, 14,    │      1,664 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 14, 14,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv2     │ (None, 14, 14,    │      3,744 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 14, 14,    │      1,664 │ block4b_dwconv2[… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 14, 14,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 416)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 416) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 26)  │     10,842 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 416) │     11,232 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 14, 14,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 416)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 14, 14,    │     43,264 │ block4b_se_excit… │
# │ (Conv2D)            │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 14, 14,    │        416 │ block4b_project_… │
# │ (BatchNormalizatio… │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 14, 14,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 14, 14,    │          0 │ block4b_drop[0][… │
# │                     │ 104)              │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 14, 14,    │     43,264 │ block4b_add[0][0] │
# │ (Conv2D)            │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 14, 14,    │      1,664 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 14, 14,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv2     │ (None, 14, 14,    │      3,744 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 14, 14,    │      1,664 │ block4c_dwconv2[… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 14, 14,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 416)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 416) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 26)  │     10,842 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 416) │     11,232 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 14, 14,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 416)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 14, 14,    │     43,264 │ block4c_se_excit… │
# │ (Conv2D)            │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 14, 14,    │        416 │ block4c_project_… │
# │ (BatchNormalizatio… │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 14, 14,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 14, 14,    │          0 │ block4c_drop[0][… │
# │                     │ 104)              │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_conv │ (None, 14, 14,    │     43,264 │ block4c_add[0][0] │
# │ (Conv2D)            │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_bn   │ (None, 14, 14,    │      1,664 │ block4d_expand_c… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_act… │ (None, 14, 14,    │          0 │ block4d_expand_b… │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_dwconv2     │ (None, 14, 14,    │      3,744 │ block4d_expand_a… │
# │ (DepthwiseConv2D)   │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_bn          │ (None, 14, 14,    │      1,664 │ block4d_dwconv2[… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_activation  │ (None, 14, 14,    │          0 │ block4d_bn[0][0]  │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_squeeze  │ (None, 416)       │          0 │ block4d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_reshape  │ (None, 1, 1, 416) │          0 │ block4d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_reduce   │ (None, 1, 1, 26)  │     10,842 │ block4d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_expand   │ (None, 1, 1, 416) │     11,232 │ block4d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_excite   │ (None, 14, 14,    │          0 │ block4d_activati… │
# │ (Multiply)          │ 416)              │            │ block4d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_project_co… │ (None, 14, 14,    │     43,264 │ block4d_se_excit… │
# │ (Conv2D)            │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_project_bn  │ (None, 14, 14,    │        416 │ block4d_project_… │
# │ (BatchNormalizatio… │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_drop        │ (None, 14, 14,    │          0 │ block4d_project_… │
# │ (Dropout)           │ 104)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_add (Add)   │ (None, 14, 14,    │          0 │ block4d_drop[0][… │
# │                     │ 104)              │            │ block4c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 14, 14,    │     64,896 │ block4d_add[0][0] │
# │ (Conv2D)            │ 624)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 14, 14,    │      2,496 │ block5a_expand_c… │
# │ (BatchNormalizatio… │ 624)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 14, 14,    │          0 │ block5a_expand_b… │
# │ (Activation)        │ 624)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv2     │ (None, 14, 14,    │      5,616 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │ 624)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 14, 14,    │      2,496 │ block5a_dwconv2[… │
# │ (BatchNormalizatio… │ 624)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 14, 14,    │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │ 624)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 624)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 624) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 26)  │     16,250 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 624) │     16,848 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 14, 14,    │          0 │ block5a_activati… │
# │ (Multiply)          │ 624)              │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 14, 14,    │     74,880 │ block5a_se_excit… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 14, 14,    │        480 │ block5a_project_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 14, 14,    │     86,400 │ block5a_project_… │
# │ (Conv2D)            │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 14, 14,    │      2,880 │ block5b_expand_c… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 14, 14,    │          0 │ block5b_expand_b… │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv2     │ (None, 14, 14,    │      6,480 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 14, 14,    │      2,880 │ block5b_dwconv2[… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 14, 14,    │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 720)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 720) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 30)  │     21,630 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 720) │     22,320 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 14, 14,    │          0 │ block5b_activati… │
# │ (Multiply)          │ 720)              │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 14, 14,    │     86,400 │ block5b_se_excit… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 14, 14,    │        480 │ block5b_project_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 14, 14,    │          0 │ block5b_project_… │
# │ (Dropout)           │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 14, 14,    │          0 │ block5b_drop[0][… │
# │                     │ 120)              │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 14, 14,    │     86,400 │ block5b_add[0][0] │
# │ (Conv2D)            │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 14, 14,    │      2,880 │ block5c_expand_c… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 14, 14,    │          0 │ block5c_expand_b… │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv2     │ (None, 14, 14,    │      6,480 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 14, 14,    │      2,880 │ block5c_dwconv2[… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 14, 14,    │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 720)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 720) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 30)  │     21,630 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 720) │     22,320 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 14, 14,    │          0 │ block5c_activati… │
# │ (Multiply)          │ 720)              │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 14, 14,    │     86,400 │ block5c_se_excit… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 14, 14,    │        480 │ block5c_project_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 14, 14,    │          0 │ block5c_project_… │
# │ (Dropout)           │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 14, 14,    │          0 │ block5c_drop[0][… │
# │                     │ 120)              │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_expand_conv │ (None, 14, 14,    │     86,400 │ block5c_add[0][0] │
# │ (Conv2D)            │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_expand_bn   │ (None, 14, 14,    │      2,880 │ block5d_expand_c… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_expand_act… │ (None, 14, 14,    │          0 │ block5d_expand_b… │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_dwconv2     │ (None, 14, 14,    │      6,480 │ block5d_expand_a… │
# │ (DepthwiseConv2D)   │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_bn          │ (None, 14, 14,    │      2,880 │ block5d_dwconv2[… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_activation  │ (None, 14, 14,    │          0 │ block5d_bn[0][0]  │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_squeeze  │ (None, 720)       │          0 │ block5d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_reshape  │ (None, 1, 1, 720) │          0 │ block5d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_reduce   │ (None, 1, 1, 30)  │     21,630 │ block5d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_expand   │ (None, 1, 1, 720) │     22,320 │ block5d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_se_excite   │ (None, 14, 14,    │          0 │ block5d_activati… │
# │ (Multiply)          │ 720)              │            │ block5d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_project_co… │ (None, 14, 14,    │     86,400 │ block5d_se_excit… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_project_bn  │ (None, 14, 14,    │        480 │ block5d_project_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_drop        │ (None, 14, 14,    │          0 │ block5d_project_… │
# │ (Dropout)           │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5d_add (Add)   │ (None, 14, 14,    │          0 │ block5d_drop[0][… │
# │                     │ 120)              │            │ block5c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_expand_conv │ (None, 14, 14,    │     86,400 │ block5d_add[0][0] │
# │ (Conv2D)            │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_expand_bn   │ (None, 14, 14,    │      2,880 │ block5e_expand_c… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_expand_act… │ (None, 14, 14,    │          0 │ block5e_expand_b… │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_dwconv2     │ (None, 14, 14,    │      6,480 │ block5e_expand_a… │
# │ (DepthwiseConv2D)   │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_bn          │ (None, 14, 14,    │      2,880 │ block5e_dwconv2[… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_activation  │ (None, 14, 14,    │          0 │ block5e_bn[0][0]  │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_squeeze  │ (None, 720)       │          0 │ block5e_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_reshape  │ (None, 1, 1, 720) │          0 │ block5e_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_reduce   │ (None, 1, 1, 30)  │     21,630 │ block5e_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_expand   │ (None, 1, 1, 720) │     22,320 │ block5e_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_se_excite   │ (None, 14, 14,    │          0 │ block5e_activati… │
# │ (Multiply)          │ 720)              │            │ block5e_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_project_co… │ (None, 14, 14,    │     86,400 │ block5e_se_excit… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_project_bn  │ (None, 14, 14,    │        480 │ block5e_project_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_drop        │ (None, 14, 14,    │          0 │ block5e_project_… │
# │ (Dropout)           │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5e_add (Add)   │ (None, 14, 14,    │          0 │ block5e_drop[0][… │
# │                     │ 120)              │            │ block5d_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_expand_conv │ (None, 14, 14,    │     86,400 │ block5e_add[0][0] │
# │ (Conv2D)            │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_expand_bn   │ (None, 14, 14,    │      2,880 │ block5f_expand_c… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_expand_act… │ (None, 14, 14,    │          0 │ block5f_expand_b… │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_dwconv2     │ (None, 14, 14,    │      6,480 │ block5f_expand_a… │
# │ (DepthwiseConv2D)   │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_bn          │ (None, 14, 14,    │      2,880 │ block5f_dwconv2[… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_activation  │ (None, 14, 14,    │          0 │ block5f_bn[0][0]  │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_se_squeeze  │ (None, 720)       │          0 │ block5f_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_se_reshape  │ (None, 1, 1, 720) │          0 │ block5f_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_se_reduce   │ (None, 1, 1, 30)  │     21,630 │ block5f_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_se_expand   │ (None, 1, 1, 720) │     22,320 │ block5f_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_se_excite   │ (None, 14, 14,    │          0 │ block5f_activati… │
# │ (Multiply)          │ 720)              │            │ block5f_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_project_co… │ (None, 14, 14,    │     86,400 │ block5f_se_excit… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_project_bn  │ (None, 14, 14,    │        480 │ block5f_project_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_drop        │ (None, 14, 14,    │          0 │ block5f_project_… │
# │ (Dropout)           │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5f_add (Add)   │ (None, 14, 14,    │          0 │ block5f_drop[0][… │
# │                     │ 120)              │            │ block5e_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 14, 14,    │     86,400 │ block5f_add[0][0] │
# │ (Conv2D)            │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 14, 14,    │      2,880 │ block6a_expand_c… │
# │ (BatchNormalizatio… │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 14, 14,    │          0 │ block6a_expand_b… │
# │ (Activation)        │ 720)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv2     │ (None, 7, 7, 720) │      6,480 │ block6a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 7, 7, 720) │      2,880 │ block6a_dwconv2[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 7, 7, 720) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 720)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 720) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 30)  │     21,630 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ...
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_se_excite   │ (None, 7, 7,      │          0 │ block6f_activati… │
# │ (Multiply)          │ 1248)             │            │ block6f_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_project_co… │ (None, 7, 7, 208) │    259,584 │ block6f_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_project_bn  │ (None, 7, 7, 208) │        832 │ block6f_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_drop        │ (None, 7, 7, 208) │          0 │ block6f_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6f_add (Add)   │ (None, 7, 7, 208) │          0 │ block6f_drop[0][… │
# │                     │                   │            │ block6e_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_expand_conv │ (None, 7, 7,      │    259,584 │ block6f_add[0][0] │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_expand_bn   │ (None, 7, 7,      │      4,992 │ block6g_expand_c… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_expand_act… │ (None, 7, 7,      │          0 │ block6g_expand_b… │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_dwconv2     │ (None, 7, 7,      │     11,232 │ block6g_expand_a… │
# │ (DepthwiseConv2D)   │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_bn          │ (None, 7, 7,      │      4,992 │ block6g_dwconv2[… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_activation  │ (None, 7, 7,      │          0 │ block6g_bn[0][0]  │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_squeeze  │ (None, 1248)      │          0 │ block6g_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_reshape  │ (None, 1, 1,      │          0 │ block6g_se_squee… │
# │ (Reshape)           │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_reduce   │ (None, 1, 1, 52)  │     64,948 │ block6g_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_expand   │ (None, 1, 1,      │     66,144 │ block6g_se_reduc… │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_se_excite   │ (None, 7, 7,      │          0 │ block6g_activati… │
# │ (Multiply)          │ 1248)             │            │ block6g_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_project_co… │ (None, 7, 7, 208) │    259,584 │ block6g_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_project_bn  │ (None, 7, 7, 208) │        832 │ block6g_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_drop        │ (None, 7, 7, 208) │          0 │ block6g_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6g_add (Add)   │ (None, 7, 7, 208) │          0 │ block6g_drop[0][… │
# │                     │                   │            │ block6f_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_expand_conv │ (None, 7, 7,      │    259,584 │ block6g_add[0][0] │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_expand_bn   │ (None, 7, 7,      │      4,992 │ block6h_expand_c… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_expand_act… │ (None, 7, 7,      │          0 │ block6h_expand_b… │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_dwconv2     │ (None, 7, 7,      │     11,232 │ block6h_expand_a… │
# │ (DepthwiseConv2D)   │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_bn          │ (None, 7, 7,      │      4,992 │ block6h_dwconv2[… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_activation  │ (None, 7, 7,      │          0 │ block6h_bn[0][0]  │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_squeeze  │ (None, 1248)      │          0 │ block6h_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_reshape  │ (None, 1, 1,      │          0 │ block6h_se_squee… │
# │ (Reshape)           │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_reduce   │ (None, 1, 1, 52)  │     64,948 │ block6h_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_expand   │ (None, 1, 1,      │     66,144 │ block6h_se_reduc… │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_se_excite   │ (None, 7, 7,      │          0 │ block6h_activati… │
# │ (Multiply)          │ 1248)             │            │ block6h_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_project_co… │ (None, 7, 7, 208) │    259,584 │ block6h_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_project_bn  │ (None, 7, 7, 208) │        832 │ block6h_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_drop        │ (None, 7, 7, 208) │          0 │ block6h_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6h_add (Add)   │ (None, 7, 7, 208) │          0 │ block6h_drop[0][… │
# │                     │                   │            │ block6g_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_expand_conv │ (None, 7, 7,      │    259,584 │ block6h_add[0][0] │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_expand_bn   │ (None, 7, 7,      │      4,992 │ block6i_expand_c… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_expand_act… │ (None, 7, 7,      │          0 │ block6i_expand_b… │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_dwconv2     │ (None, 7, 7,      │     11,232 │ block6i_expand_a… │
# │ (DepthwiseConv2D)   │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_bn          │ (None, 7, 7,      │      4,992 │ block6i_dwconv2[… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_activation  │ (None, 7, 7,      │          0 │ block6i_bn[0][0]  │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_se_squeeze  │ (None, 1248)      │          0 │ block6i_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_se_reshape  │ (None, 1, 1,      │          0 │ block6i_se_squee… │
# │ (Reshape)           │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_se_reduce   │ (None, 1, 1, 52)  │     64,948 │ block6i_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_se_expand   │ (None, 1, 1,      │     66,144 │ block6i_se_reduc… │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_se_excite   │ (None, 7, 7,      │          0 │ block6i_activati… │
# │ (Multiply)          │ 1248)             │            │ block6i_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_project_co… │ (None, 7, 7, 208) │    259,584 │ block6i_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_project_bn  │ (None, 7, 7, 208) │        832 │ block6i_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_drop        │ (None, 7, 7, 208) │          0 │ block6i_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6i_add (Add)   │ (None, 7, 7, 208) │          0 │ block6i_drop[0][… │
# │                     │                   │            │ block6h_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_expand_conv │ (None, 7, 7,      │    259,584 │ block6i_add[0][0] │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_expand_bn   │ (None, 7, 7,      │      4,992 │ block6j_expand_c… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_expand_act… │ (None, 7, 7,      │          0 │ block6j_expand_b… │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_dwconv2     │ (None, 7, 7,      │     11,232 │ block6j_expand_a… │
# │ (DepthwiseConv2D)   │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_bn          │ (None, 7, 7,      │      4,992 │ block6j_dwconv2[… │
# │ (BatchNormalizatio… │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_activation  │ (None, 7, 7,      │          0 │ block6j_bn[0][0]  │
# │ (Activation)        │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_se_squeeze  │ (None, 1248)      │          0 │ block6j_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_se_reshape  │ (None, 1, 1,      │          0 │ block6j_se_squee… │
# │ (Reshape)           │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_se_reduce   │ (None, 1, 1, 52)  │     64,948 │ block6j_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_se_expand   │ (None, 1, 1,      │     66,144 │ block6j_se_reduc… │
# │ (Conv2D)            │ 1248)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_se_excite   │ (None, 7, 7,      │          0 │ block6j_activati… │
# │ (Multiply)          │ 1248)             │            │ block6j_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_project_co… │ (None, 7, 7, 208) │    259,584 │ block6j_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_project_bn  │ (None, 7, 7, 208) │        832 │ block6j_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_drop        │ (None, 7, 7, 208) │          0 │ block6j_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6j_add (Add)   │ (None, 7, 7, 208) │          0 │ block6j_drop[0][… │
# │                     │                   │            │ block6i_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 7, 7,      │    292,864 │ block6j_add[0][0] │
# │                     │ 1408)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 7, 7,      │      5,632 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1408)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 7, 7,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1408)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,769,374 (33.45 MB)
#  Trainable params: 7,966,188 (30.39 MB)
#  Non-trainable params: 803,186 (3.06 MB)

# %%
acc = history.history['accuracy']          # Extract training accuracy from history
val_acc = history.history['val_accuracy']  # Extract validation accuracy from history
loss = history.history['loss']             # Extract training loss from history
val_loss = history.history['val_loss']     # Extract validation loss from history

epochs_range = range(len(acc))             # Define range for epochs based on accuracy length

plt.figure(figsize=(10,8))                 # Set overall figure size for visualization

plt.subplot(1,2,1)                         # Create first subplot (1 row, 2 columns, position 1)
plt.plot(epochs_range, acc, label='Training Accuracy')       # Plot training accuracy
plt.plot(epochs_range, val_acc, label='Validation Accuracy') # Plot validation accuracy
plt.legend(loc='lower right')              # Place legend in lower-right corner
plt.title('Training vs Validation Accuracy') # Add title for accuracy plot

plt.subplot(1,2,2)                         # Create second subplot (1 row, 2 columns, position 2)
plt.plot(epochs_range, loss, label='Training Loss')         # Plot training loss
plt.plot(epochs_range, val_loss, label='Validation Loss')   # Plot validation loss
plt.legend(loc='upper right')              # Place legend in upper-right corner
plt.title('Training vs Validation Loss')   # Add title for loss plot

plt.show()                                 # Display the plots

# %%
loss, accuracy = model.evaluate(test_ds_eval)
print(f'Test accuracy is{accuracy:.4f}, Test loss is {loss:.4f}')
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 630ms/step - accuracy: 0.9189 - loss: 0.2290
# Test accuracy is0.9375, Test loss is 0.2220

# %%
# Extract true labels from all batches in the test dataset
y_true = np.concatenate([y.numpy() for x, y in test_ds_eval], axis=0)  # Convert Tensor labels to NumPy array and concatenate them

# Get predictions as probabilities from the model
y_pred_probs = model.predict(test_ds_eval)  # Predict class probabilities for each sample in the test dataset

# Convert probabilities to predicted class indices
y_pred = np.argmax(y_pred_probs, axis=1)  # Select the class with the highest probability for each sample

# Compute the confusion matrix to evaluate classification performance
cm = confusion_matrix(y_true, y_pred)  # Generate confusion matrix comparing true labels to predicted labels

# Print metrics to assess model performance
print(cm)  # Display confusion matrix
print(classification_report(y_true, y_pred))  # Print precision, recall, and F1-score for each class
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 575ms/step
# [[29  0  1  1  0  1]
#  [ 0 43  1  0  2  0]
#  [ 0  0 45  0  0  0]
#  [ 0  0  0 56  0  1]
#  [ 0  2  3  0 48  2]
#  [ 2  0  0  0  0 19]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92        32
#            1       0.96      0.93      0.95        46
#            2       0.90      1.00      0.95        45
#            3       0.98      0.98      0.98        57
#            4       0.96      0.87      0.91        55
#            5       0.83      0.90      0.86        21
#
#     accuracy                           0.94       256
#    macro avg       0.93      0.93      0.93       256
# weighted avg       0.94      0.94      0.94       256

# %%
plt.figure(figsize=(10,8))  # Set figure size for better visualization

sns.heatmap(cm, annot=True, fmt='d',  # Create heatmap using confusion matrix
            xticklabels=class_names,  # Set class names for x-axis (predicted labels)
            yticklabels=class_names,  # Set class names for y-axis (true labels)
            cmap='Blues')  # Use a blue colormap for better contrast

plt.xlabel('Predicted')  # Label x-axis as Predicted classes
plt.ylabel('True')  # Label y-axis as True classes
plt.title('Confusion Matrix')  # Add title to the heatmap
plt.show()  # Display the plot

# %%
# Extract class names from the training dataset
class_names = train_ds.class_names  

# Take one batch of images and labels from the test dataset for evaluation
for images, labels in test_ds_eval.take(1):  

    # Generate predictions for the batch of images
    predictions = model.predict(images)  

    # Get the predicted class index for each image
    pred_labels = tf.argmax(predictions, axis=1)  

    # Loop through the first 8 images in the batch
    for i in range(8):  
        plt.imshow(images[i].numpy().astype("uint8"))  # Convert and display image
        plt.title(f"True: {class_names[labels[i]]}, Pred: {class_names[pred_labels[i]]}")  # Show actual and predicted class
        plt.axis("off")  # Hide axes for better visualization
        plt.show()  # Display the image with title
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
# Save model in Keras format with architecture, weights, and training configuration
model.save('Effiicientnetv2b2.keras')

# Load your Keras model
model = tf.keras.models.load_model('Effiicientnetv2b2.keras')

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in d:\anaconda\lib\site-packages (5.35.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in d:\anaconda\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\anaconda\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in d:\anaconda\lib\site-packages (from gradio) (0.2.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in d:\anaconda\lib\site-packages (from gradio) (0.115.14)
# Requirement already satisfied: ffmpy in d:\anaconda\lib\site-packages (from gradio) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.4 in d:\anaconda\lib\site-packages (from gradio) (1.10.4)
# Requirement already satisfied: groovy~=0.1 in d:\anaconda\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in d:\anaconda\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in d:\anaconda\lib\site-packages (from gradio) (0.33.2)
# Requirement already satisfied: jinja2<4.0 in d:\anaconda\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\anaconda\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in d:\anaconda\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in d:\anaconda\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in d:\anaconda\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in d:\anaconda\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.10.3)
# Requirement already satisfied: pydub in d:\anaconda\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in d:\anaconda\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\anaconda\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in d:\anaconda\lib\site-packages (from gradio) (0.12.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in d:\anaconda\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in d:\anaconda\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in d:\anaconda\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\anaconda\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in d:\anaconda\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in d:\anaconda\lib\site-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in d:\anaconda\lib\site-packages (from gradio-client==1.10.4->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in d:\anaconda\lib\site-packages (from gradio-client==1.10.4->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\anaconda\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx>=0.24.1->gradio) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.17.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)

# %%
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

# %%
def classify_image(img):  
    # Resize image to 124x124 pixels (Note: Comment says 128x128, but code resizes to 124x124)
    img = img.resize((224, 224))  
    
    # Convert image to a NumPy array with float32 dtype
    img_array = np.array(img, dtype=np.float32)  
    img_array = preprocess_input(img_array)
    
    # Expand dimensions to match model input shape (adds a batch dimension)
    img_array = np.expand_dims(img_array, axis=0)  
    
    # Make a prediction using the trained model
    prediction = model.predict(img_array)  
    
    # Get the index of the highest predicted probability
    predicted_class_index = np.argmax(prediction)  
    
    # Map the predicted index to its corresponding class name
    predicted_class_name = class_names[predicted_class_index]  
    
    # Extract confidence score (probability of the predicted class)
    confidence = prediction[0][predicted_class_index]  
    
    # Return formatted prediction result with confidence score
    return f"Predicted: {predicted_class_name} (Confidence: {confidence:.2f})"

# %%
iface = gr.Interface(  
    fn=classify_image,  # Function to classify image using the trained model  
    inputs=gr.Image(type="pil"),  # Accepts input as a PIL image  
    outputs="text"  # Outputs prediction as text  
)  

# Launch the interface  
iface.launch()  # Start the Gradio interface for user interaction
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
